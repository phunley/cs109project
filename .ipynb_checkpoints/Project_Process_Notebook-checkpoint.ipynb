# %% [markdown]
# #How to Draft the Next NFL Pro Bowler
#
# May need to modify this depending on whether we actually get strong results

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import statsmodels.api as sm

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# special matplotlib argument for improved plots
from matplotlib import rcParams

# %% [markdown]
# Our main data file contains results from the NFL Scouting Combine from 1999 through 2015.

# %%
nflcomb = pd.read_csv("combine.csv")
nflcomb.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms    ...     vertical  broad  \
# 0             9                 69     205     0    ...         42.5    130
# 1             0                 72     198     0    ...          0.0      0
# 2             0                 72     221     0    ...         39.0    121
# 3             1                 73     227     0    ...         36.0    121
# 4             8                 68     180     0    ...         34.0    121
#
#    bench  round        college  pick  pickround  picktotal  wonderlic  \
# ...
